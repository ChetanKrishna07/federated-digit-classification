# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
results = pd.read_csv("results.csv", index_col="Strategy")

# %%
results
# Out:
#             Accuracy 1  Accuracy 2  Accuracy 3  Average Accuracy    Time
# Strategy
# FedAvg           0.958      0.9700      0.9700          0.966000  79.330
# FedAdam          0.206      0.6812      0.2937          0.393633  82.230
# FedYogi          0.129      0.3480      0.7490          0.408667  88.248
# FedAdagrad       0.198      0.3440      0.8470          0.463000  98.200
# FedProx          0.960      0.9770      0.9800          0.972333  85.470
# FedMedian        0.950      0.9700      0.9700          0.963333  80.720
# FedOpt           0.950      0.9700      0.9800          0.966667  85.290
# Standalone       0.983      0.9830      0.9830          0.983000  95.000

# %%
results.drop("Time",axis=1).plot(kind='bar').legend(bbox_to_anchor=(1, 1))
plt.title("Model Performance")
plt.show()

# %%
results.iloc[:,-1].plot(kind='bar')
plt.ylabel("Time taken(s)")
plt.title("Model Speeds")
plt.show()
